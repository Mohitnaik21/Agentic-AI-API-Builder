# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohitnaik21/Agentic-AI-API-Builder/blob/main/Agentic_AI_API_Builder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install crewai sentence-transformers faiss-cpu fastapi uvicorn nest-asyncio pyngrok transformers accelerate torch google-generativeai
# Out:
# Requirement already satisfied: crewai in /usr/local/lib/python3.11/dist-packages (0.102.0)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.11/dist-packages (1.10.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.11/dist-packages (0.115.11)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.11/dist-packages (0.34.0)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.11/dist-packages (7.2.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.3.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /usr/local/lib/python3.11/dist-packages (from crewai) (4.8.1)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.9.0)
# Requirement already satisfied: chromadb>=0.5.23 in /usr/local/lib/python3.11/dist-packages (from crewai) (0.6.3)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from crewai) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.7.2)
# Requirement already satisfied: json-repair>=0.25.2 in /usr/local/lib/python3.11/dist-packages (from crewai) (0.39.1)
# Requirement already satisfied: json5>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (0.10.0)
# Requirement already satisfied: jsonref>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.1.0)
# Requirement already satisfied: litellm==1.60.2 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.60.2)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.61.1)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.30.0)
# Requirement already satisfied: pdfplumber>=0.11.4 in /usr/local/lib/python3.11/dist-packages (from crewai) (0.11.5)
# Requirement already satisfied: pydantic>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from crewai) (2.10.6)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.0.1)
# Requirement already satisfied: pyvis>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.11/dist-packages (from crewai) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.2.0)
# Requirement already satisfied: tomli>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from crewai) (2.2.1)
# Requirement already satisfied: uv>=0.4.25 in /usr/local/lib/python3.11/dist-packages (from crewai) (0.6.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (3.11.13)
# Requirement already satisfied: httpx<0.28.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (0.27.2)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (8.5.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (3.1.5)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (4.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (0.9.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (0.21.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.28.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (0.46.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from fastapi) (4.12.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.24.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.160.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (5.29.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.0)
# Requirement already satisfied: cryptography>=43.0.1 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (43.0.3)
# Requirement already satisfied: pyjwt>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: urllib3>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (2.3.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (0.7.6)
# Requirement already satisfied: posthog>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (3.18.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.20.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (9.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (3.10.15)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.68.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (0.8.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (2.27.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.60.2->crewai) (3.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.22.0->crewai) (1.2.18)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.30.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-proto==1.30.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.30.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk>=1.22.0->crewai) (0.51b0)
# Requirement already satisfied: pdfminer.six==20231228 in /usr/local/lib/python3.11/dist-packages (from pdfplumber>=0.11.4->crewai) (20231228)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from pdfplumber>=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai) (3.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (7.34.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (4.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (1.18.3)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai) (1.17.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.62.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (1.0.7)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm==1.60.2->crewai) (3.21.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (0.23.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.8.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.9)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (25.2.10)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (0.51b0)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from posthog>=2.4.0->chromadb>=0.5.23->crewai) (2.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (14.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.11/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (10.0)

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np
import requests
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import google.generativeai as genai

GOOGLE_API_KEY = "Add your key here"
genai.configure(api_key=GOOGLE_API_KEY)

# models = genai.list_models()
# for model in models:
#     print(model.name)

# %%
# Download Public API dataset from GitHub
url = "https://raw.githubusercontent.com/public-apis/public-apis/master/README.md"
response = requests.get(url)

# Extract API Names & Descriptions
api_data = []
for line in response.text.split("\n"):
    if "| [" in line and "](https://" in line:
        parts = line.split("|")
        if len(parts) > 2:
            api_name = parts[1].split("[")[1].split("]")[0]
            api_url = parts[1].split("(")[1].split(")")[0]
            api_desc = parts[2].strip()
            api_data.append({"API Name": api_name, "API Endpoint": api_url, "Description": api_desc})

# Save as CSV
df = pd.DataFrame(api_data)
df.to_csv("public_apis.csv", index=False)

print("✅ Public API dataset saved as 'public_apis.csv'")
# Out:
# ✅ Public API dataset saved as 'public_apis.csv'

# %%
class APIRetrievalAgent:
    def __init__(self):
        # Load embedding model
        self.embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

        # Load API dataset
        file_path = "public_apis.csv"
        self.api_df = pd.read_csv(file_path)
        self.api_df["text"] = self.api_df["API Name"] + " - " + self.api_df["Description"]

        # Generate embeddings
        api_texts = self.api_df["text"].tolist()
        api_embeddings = self.embedding_model.encode(api_texts, convert_to_numpy=True)

        # Create FAISS index
        dimension = api_embeddings.shape[1]
        self.faiss_index = faiss.IndexFlatL2(dimension)
        self.faiss_index.add(api_embeddings)

        # Store metadata
        self.api_metadata = self.api_df[["API Name", "API Endpoint", "Description"]]

    def retrieve_apis(self, project_request, top_k=5):
        """Retrieve relevant APIs based on user request."""
        query_embedding = self.embedding_model.encode([project_request], convert_to_numpy=True)
        distances, indices = self.faiss_index.search(query_embedding, top_k)

        results = []
        for idx in indices[0]:
            if idx >= 0:
                api_data = self.api_metadata.iloc[idx].to_dict()
                results.append(api_data)

        return results

# %%
class BackendCodeAgent:
    def generate_backend_code(self, api_list):
        """Generate FastAPI backend code integrating selected APIs."""

        if not GOOGLE_API_KEY:
            raise ValueError("Google API key is missing. Set GOOGLE_API_KEY before running.")

        prompt = """You are a backend developer. Generate a Python FastAPI application that interacts with the following APIs:

        Requirements:
        - Do not copy existing code from external sources.
        - Write original and well-structured FastAPI code.
        - Ensure API calls are properly handled.
        - Return responses as JSON.
        - Implement error handling.

        The APIs to integrate are:\n\n"""

        for api in api_list:
            prompt += f"- {api['API Name']} ({api['API Endpoint']}): {api['Description']}\n"

        # Use less restrictive model & handle empty response
        model = genai.GenerativeModel("gemini-1.5-flash-latest")  # Change model to flash for more flexibility
        response = model.generate_content(prompt)
        # Debug: Print full response to see what is happening
        print("🔹 Raw AI Response (Backend):", response)


        if not response.candidates or not response.candidates[0].content.parts:
            raise ValueError("⚠️ AI model returned an empty response. Try modifying the prompt or using a different model.")


        print("\n✅ Generated Backend Code:\n", response.text)

        return response.text

# %%
class FrontendCodeAgent:
    def generate_frontend_code(self, backend_urls):
        """Generate a React frontend that fetches data from multiple backend APIs."""

        if not GOOGLE_API_KEY:
            raise ValueError("Google API key is missing. Set GOOGLE_API_KEY before running.")

        prompt = """You are a frontend React developer. Write a React component that:

        - Fetches data from multiple FastAPI endpoints.
        - Uses React hooks (`useState`, `useEffect`).
        - Displays API responses in a table.
        - Handles errors and loading states.

        APIs to integrate:\n\n"""

        for api_name, backend_url in backend_urls.items():
            prompt += f"- {api_name}: Fetch data from {backend_url}\n"

        # Use less restrictive model & handle empty response
        model = genai.GenerativeModel("gemini-1.5-flash-latest")
        response = model.generate_content(prompt)
        # Debug: Print full response to see what is happening
        print("🔹 Raw AI Response (Frontend):", response)

        if not response.candidates or not response.candidates[0].content.parts:
            raise ValueError("⚠️ AI model returned an empty response. Try modifying the prompt or using a different model.")

        print("\n✅ Generated Frontend Code:\n", response.text)
        return response.text

# %%
class ProjectManagerAgent:
    def __init__(self):
        self.api_agent = APIRetrievalAgent()
        self.backend_agent = BackendCodeAgent()
        self.frontend_agent = FrontendCodeAgent()

    def build_full_stack_app(self, project_request):
        print("📌 Understanding the request...")
        relevant_apis = self.api_agent.retrieve_apis(project_request, top_k=5)

        if not relevant_apis:
            return "❌ No relevant APIs found!"

        print("\n✅ APIs Retrieved:")
        for api in relevant_apis:
            print(f"🔹 {api['API Name']} → {api['API Endpoint']}")

        print("\n🚀 Generating Backend Code...")
        backend_code = self.backend_agent.generate_backend_code(relevant_apis)
        print("\n✅ Backend Code Generated.", backend_code)

        backend_urls = {api["API Name"]: f"http://127.0.0.1:8000/{api['API Name'].replace(' ', '_').lower()}" for api in relevant_apis}

        print("\n🎨 Generating Frontend Code...")
        frontend_code = self.frontend_agent.generate_frontend_code(backend_urls)
        print("\n✅ Frontend Code Generated.", frontend_code)

        return backend_code, frontend_code

# %%
pm_agent = ProjectManagerAgent()
backend_code, frontend_code = pm_agent.build_full_stack_app(
    "Build a weather dashboard using public APIs."
)
# Out:
# 📌 Understanding the request...
#
# ✅ APIs Retrieved:
# 🔹 weather-api → https://github.com/robertoduessmann/weather-api
# 🔹 Tomorrow → https://docs.tomorrow.io
# 🔹 WeatherAPI → https://www.weatherapi.com/
# 🔹 apilayer weatherstack → https://weatherstack.com/
# 🔹 Weatherstack → https://weatherstack.com/?utm_source=Github&utm_medium=Referral&utm_campaign=Public-apis-repo-Best-sellers
#
# 🚀 Generating Backend Code...
# 🔹 Raw AI Response (Backend): response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "This solution demonstrates the basic structure for interacting with multiple weather APIs.  Due to the limitations of providing API keys and the varying authentication methods of the listed APIs, I cannot fully implement requests to all of them.  This example shows how to structure your FastAPI application to handle multiple API calls, including error handling, but will require you to replace placeholders with your actual API keys and endpoints.\n\n```python\nfrom fastapi import FastAPI, HTTPException\nfrom pydantic import BaseModel\nimport httpx\nimport json\n\napp = FastAPI()\n\n# Replace with your actual API keys.  Note that some APIs require specific headers etc.\nWEATHER_API_KEY = \"YOUR_WEATHER_API_KEY\"  # Example - replace with your actual key if used\nTOMORROW_IO_KEY = \"YOUR_TOMORROW_IO_KEY\" # Example - replace with your actual key if used\nWEATHERAPI_KEY = \"YOUR_WEATHERAPI_KEY\" # Example - replace with your actual key if used\nWEATHERSTACK_KEY = \"YOUR_WEATHERSTACK_KEY\" # Example - replace with your actual key if used\n\n\nclass WeatherRequest(BaseModel):\n    location: str\n\n\nclass WeatherResponse(BaseModel):\n    location: str\n    temperature: float = None\n    description: str = None\n    error: str = None\n\n\nasync def fetch_weather_data(location, api_key, api_url, params={}):\n    try:\n        async with httpx.AsyncClient() as client:\n            response = await client.get(api_url, params={**params, \"key\": api_key})\n            response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)\n            data = response.json()\n            # Adapt this to match the structure of your specific API response\n            return data\n    except httpx.HTTPError as e:\n        return {\"error\": f\"API request failed: {e}\"}\n    except json.JSONDecodeError as e:\n        return {\"error\": f\"Invalid JSON response: {e}\"}\n    except Exception as e:\n        return {\"error\": f\"An unexpected error occurred: {e}\"}\n\n\n@app.post(\"/weather\", response_model=WeatherResponse)\nasync def get_weather(request: WeatherRequest):\n    location = request.location\n\n    # Example of calling multiple APIs.  You'll need to customize these based on each API's structure.\n    # weather_data = await fetch_weather_data(location, WEATHER_API_KEY, \"YOUR_WEATHER_API_ENDPOINT\", {\"q\":location}) # replace with your actual endpoint\n    # tomorrow_data = await fetch_weather_data(location, TOMORROW_IO_KEY, \"YOUR_TOMORROW_IO_ENDPOINT\") # replace with your actual endpoint\n    # weatherapi_data = await fetch_weather_data(location, WEATHERAPI_KEY, \"YOUR_WEATHERAPI_ENDPOINT\") # replace with your actual endpoint\n    # weatherstack_data = await fetch_weather_data(location, WEATHERSTACK_KEY, \"YOUR_WEATHERSTACK_ENDPOINT\") # replace with your actual endpoint\n\n\n    # Example using only one API (replace with your preferred and correctly configured API call)\n    weatherstack_data = await fetch_weather_data(location, WEATHERSTACK_KEY, \"http://api.weatherstack.com/current\", {\"query\":location})\n    \n    if \"error\" in weatherstack_data:\n        raise HTTPException(status_code=500, detail=weatherstack_data[\"error\"])\n\n    # Extract relevant information (adapt to your chosen API's response structure)\n    try:\n        temperature = weatherstack_data[\"current\"][\"temperature\"]\n        description = weatherstack_data[\"current\"][\"weather_descriptions\"][0]\n        return WeatherResponse(location=location, temperature=temperature, description=description)\n    except (KeyError, IndexError) as e:\n        raise HTTPException(status_code=500, detail=f\"Could not parse weather data: {e}\")\n\n\n```\n\nTo run this:\n\n1.  **Install dependencies:** `pip install fastapi uvicorn pydantic httpx`\n2.  **Replace placeholders:** Fill in the `API_KEY` variables with your actual API keys and the API endpoints in `fetch_weather_data` and the `/weather` endpoint.  \n3.  **Run the app:** ...
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "avg_logprobs": -0.2127390098390298
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 238,
#         "candidates_token_count": 1051,
#         "total_token_count": 1289
#       },
#       "model_version": "gemini-1.5-flash-latest"
#     }),
# )
#
# ✅ Generated Backend Code:
#  This solution demonstrates the basic structure for interacting with multiple weather APIs.  Due to the limitations of providing API keys and the varying authentication methods of the listed APIs, I cannot fully implement requests to all of them.  This example shows how to structure your FastAPI application to handle multiple API calls, including error handling, but will require you to replace placeholders with your actual API keys and endpoints.
#
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
# import httpx
# import json
#
# app = FastAPI()
#
# # Replace with your actual API keys.  Note that some APIs require specific headers etc.
# WEATHER_API_KEY = "YOUR_WEATHER_API_KEY"  # Example - replace with your actual key if used
# TOMORROW_IO_KEY = "YOUR_TOMORROW_IO_KEY" # Example - replace with your actual key if used
# WEATHERAPI_KEY = "YOUR_WEATHERAPI_KEY" # Example - replace with your actual key if used
# WEATHERSTACK_KEY = "YOUR_WEATHERSTACK_KEY" # Example - replace with your actual key if used
#
#
# class WeatherRequest(BaseModel):
#     location: str
#
#
# class WeatherResponse(BaseModel):
#     location: str
#     temperature: float = None
#     description: str = None
#     error: str = None
#
#
# async def fetch_weather_data(location, api_key, api_url, params={}):
#     try:
#         async with httpx.AsyncClient() as client:
#             response = await client.get(api_url, params={**params, "key": api_key})
#             response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
#             data = response.json()
#             # Adapt this to match the structure of your specific API response
#             return data
#     except httpx.HTTPError as e:
#         return {"error": f"API request failed: {e}"}
#     except json.JSONDecodeError as e:
#         return {"error": f"Invalid JSON response: {e}"}
#     except Exception as e:
#         return {"error": f"An unexpected error occurred: {e}"}
#
#
# @app.post("/weather", response_model=WeatherResponse)
# async def get_weather(request: WeatherRequest):
#     location = request.location
#
#     # Example of calling multiple APIs.  You'll need to customize these based on each API's structure.
#     # weather_data = await fetch_weather_data(location, WEATHER_API_KEY, "YOUR_WEATHER_API_ENDPOINT", {"q":location}) # replace with your actual endpoint
#     # tomorrow_data = await fetch_weather_data(location, TOMORROW_IO_KEY, "YOUR_TOMORROW_IO_ENDPOINT") # replace with your actual endpoint
#     # weatherapi_data = await fetch_weather_data(location, WEATHERAPI_KEY, "YOUR_WEATHERAPI_ENDPOINT") # replace with your actual endpoint
#     # weatherstack_data = await fetch_weather_data(location, WEATHERSTACK_KEY, "YOUR_WEATHERSTACK_ENDPOINT") # replace with your actual endpoint
#
#
#     # Example using only one API (replace with your preferred and correctly configured API call)
#     weatherstack_data = await fetch_weather_data(location, WEATHERSTACK_KEY, "http://api.weatherstack.com/current", {"query":location})
#
#     if "error" in weatherstack_data:
#         raise HTTPException(status_code=500, detail=weatherstack_data["error"])
#
#     # Extract relevant information (adapt to your chosen API's response structure)
#     try:
#         temperature = weatherstack_data["current"]["temperature"]
#         description = weatherstack_data["current"]["weather_descriptions"][0]
#         return WeatherResponse(location=location, temperature=temperature, description=description)
#     except (KeyError, IndexError) as e:
#         raise HTTPException(status_code=500, detail=f"Could not parse weather data: {e}")
#
#
# ```
#
# To run this:
#
# 1.  **Install dependencies:** `pip install fastapi uvicorn pydantic httpx`
# 2.  **Replace placeholders:** Fill in the `API_KEY` variables with your actual API keys and the API endpoints in `fetch_weather_data` and the `/weather` endpoint.
# 3.  **Run the app:** `uvicorn main:app --reload` (assuming you saved the code as `main.py`)
#
# Remember to carefully review the documentation for each API to understand its request parameters and response format.  This example provides a solid foundation for building a more robust application that integrates multiple weather APIs.  You'll need to adjust error handling and data extraction to match the specifics of each API you use.
#
#
# ✅ Backend Code Generated. This solution demonstrates the basic structure for interacting with multiple weather APIs.  Due to the limitations of providing API keys and the varying authentication methods of the listed APIs, I cannot fully implement requests to all of them.  This example shows how to structure your FastAPI application to handle multiple API calls, including error handling, but will require you to replace placeholders with your actual API keys and endpoints.
#
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
# import httpx
# import json
#
# app = FastAPI()
#
# # Replace with your actual API keys.  Note that some APIs require specific headers etc.
# WEATHER_API_KEY = "YOUR_WEATHER_API_KEY"  # Example - replace with your actual key if used
# TOMORROW_IO_KEY = "YOUR_TOMORROW_IO_KEY" # Example - replace with your actual key if used
# WEATHERAPI_KEY = "YOUR_WEATHERAPI_KEY" # Example - replace with your actual key if used
# WEATHERSTACK_KEY = "YOUR_WEATHERSTACK_KEY" # Example - replace with your actual key if used
#
#
# class WeatherRequest(BaseModel):
#     location: str
#
#
# class WeatherResponse(BaseModel):
#     location: str
#     temperature: float = None
#     description: str = None
#     error: str = None
#
#
# async def fetch_weather_data(location, api_key, api_url, params={}):
#     try:
#         async with httpx.AsyncClient() as client:
#             response = await client.get(api_url, params={**params, "key": api_key})
#             response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
#             data = response.json()
#             # Adapt this to match the structure of your specific API response
#             return data
#     except httpx.HTTPError as e:
#         return {"error": f"API request failed: {e}"}
#     except json.JSONDecodeError as e:
#         return {"error": f"Invalid JSON response: {e}"}
#     except Exception as e:
#         return {"error": f"An unexpected error occurred: {e}"}
#
#
# @app.post("/weather", response_model=WeatherResponse)
# async def get_weather(request: WeatherRequest):
#     location = request.location
#
#     # Example of calling multiple APIs.  You'll need to customize these based on each API's structure.
#     # weather_data = await fetch_weather_data(location, WEATHER_API_KEY, "YOUR_WEATHER_API_ENDPOINT", {"q":location}) # replace with your actual endpoint
#     # tomorrow_data = await fetch_weather_data(location, TOMORROW_IO_KEY, "YOUR_TOMORROW_IO_ENDPOINT") # replace with your actual endpoint
#     # weatherapi_data = await fetch_weather_data(location, WEATHERAPI_KEY, "YOUR_WEATHERAPI_ENDPOINT") # replace with your actual endpoint
#     # weatherstack_data = await fetch_weather_data(location, WEATHERSTACK_KEY, "YOUR_WEATHERSTACK_ENDPOINT") # replace with your actual endpoint
#
#
#     # Example using only one API (replace with your preferred and correctly configured API call)
#     weatherstack_data = await fetch_weather_data(location, WEATHERSTACK_KEY, "http://api.weatherstack.com/current", {"query":location})
#
#     if "error" in weatherstack_data:
#         raise HTTPException(status_code=500, detail=weatherstack_data["error"])
#
#     # Extract relevant information (adapt to your chosen API's response structure)
#     try:
#         temperature = weatherstack_data["current"]["temperature"]
#         description = weatherstack_data["current"]["weather_descriptions"][0]
#         return WeatherResponse(location=location, temperature=temperature, description=description)
#     except (KeyError, IndexError) as e:
#         raise HTTPException(status_code=500, detail=f"Could not parse weather data: {e}")
#
#
# ```
#
# To run this:
#
# 1.  **Install dependencies:** `pip install fastapi uvicorn pydantic httpx`
# 2.  **Replace placeholders:** Fill in the `API_KEY` variables with your actual API keys and the API endpoints in `fetch_weather_data` and the `/weather` endpoint.
# 3.  **Run the app:** `uvicorn main:app --reload` (assuming you saved the code as `main.py`)
#
# Remember to carefully review the documentation for each API to understand its request parameters and response format.  This example provides a solid foundation for building a more robust application that integrates multiple weather APIs.  You'll need to adjust error handling and data extraction to match the specifics of each API you use.
#
#
# 🎨 Generating Frontend Code...
# 🔹 Raw AI Response (Frontend): response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "```jsx\nimport React, { useState, useEffect } from 'react';\n\nconst APIS = [\n  { name: 'weather-api', url: 'http://127.0.0.1:8000/weather-api' },\n  { name: 'Tomorrow', url: 'http://127.0.0.1:8000/tomorrow' },\n  { name: 'WeatherAPI', url: 'http://127.0.0.1:8000/weatherapi' },\n  { name: 'apilayer weatherstack', url: 'http://127.0.0.1:8000/apilayer_weatherstack' },\n  { name: 'Weatherstack', url: 'http://127.0.0.1:8000/weatherstack' },\n];\n\nconst WeatherData = () => {\n  const [data, setData] = useState({});\n  const [loading, setLoading] = useState(true);\n  const [error, setError] = useState(null);\n\n  useEffect(() => {\n    const fetchData = async () => {\n      try {\n        const promises = APIS.map(api => \n          fetch(api.url)\n            .then(res => res.json())\n            .then(data => ({ name: api.name, data }))\n            .catch(error => ({ name: api.name, error }))\n        );\n        const results = await Promise.all(promises);\n        const dataObj = {};\n        results.forEach(result => {\n          if (result.error) {\n            dataObj[result.name] = { error: result.error.message || result.error };\n          } else {\n            dataObj[result.name] = result.data;\n          }\n        });\n        setData(dataObj);\n      } catch (err) {\n        setError(err);\n      } finally {\n        setLoading(false);\n      }\n    };\n\n    fetchData();\n  }, []);\n\n  if (loading) {\n    return <div>Loading...</div>;\n  }\n\n  if (error) {\n    return <div>Error: {error.message}</div>;\n  }\n\n  return (\n    <table>\n      <thead>\n        <tr>\n          <th>API</th>\n          <th>Data</th>\n        </tr>\n      </thead>\n      <tbody>\n        {Object.entries(data).map(([apiName, apiData]) => (\n          <tr key={apiName}>\n            <td>{apiName}</td>\n            <td>\n              {apiData.error ? (\n                <span style={{ color: 'red' }}>Error: {apiData.error}</span>\n              ) : (\n                <pre>{JSON.stringify(apiData, null, 2)}</pre>\n              )}\n            </td>\n          </tr>\n        ))}\n      </tbody>\n    </table>\n  );\n};\n\nexport default WeatherData;\n```\n\n**Before running:**\n\n1.  **Make sure you have a FastAPI server running on `http://127.0.0.1:8000` with the specified endpoints.**  This code assumes those endpoints exist and return JSON data.  You'll need to create those API endpoints yourself.  A simple example for one endpoint might be:\n\n    ```python\n    from fastapi import FastAPI\n    app = FastAPI()\n\n    @app.get(\"/weather-api\")\n    async def weather_api():\n        return {\"temperature\": 25, \"condition\": \"Sunny\"}\n    ```\n\n2.  **Install React and necessary packages:**  You'll need to have a React project set up.  If not, use `create-react-app`:\n\n    ```bash\n    npx create-react-app my-weather-app\n    cd my-weather-app\n    ```\n\n3.  **Replace the placeholder API URLs** if your FastAPI server is running on a different address or port.\n\n4.  **Import and render the component** in your main app file (e.g., `App.js` or `src/App.js`):\n\n    ```jsx\n    import React from 'react';\n    import WeatherData from './WeatherData'; // Adjust path as needed\n\n    function App() {\n      return (\n        <div className=\"App\">\n          <WeatherData />\n        </div>\n      );\n    }\n\n    export default App;\n    ```\n\n5.  **Run the React app:**\n\n    ```bash\n    npm start\n    ```\n\n\nThis improved version handles errors more gracefully, displaying error messages from each API call individually, and uses `pre` tags for better formatting of JSON responses.  Remember to adjust file paths as needed for your project structure.  The error handling assumes the API returns a JSON object with an `error` property or a string message. You might need to adjust this based on your actual error responses.\n"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "citation_metadata": {
#             "citation_sources": [
#               {
#                 "start_index": 468,
#                 "end_index": 644,
#                 "uri": "https://victoriacheng15.vercel.app/posts/react-hooks-usecontext/"
#               },
#               {
#                 "start_index": 492,
#                 "end_index": 676,
#                 "uri": "https://github.com/reactplay/react-play",
#                 "license_": "MIT"
#               },
#               {
#                 "start_index": 1249,
#                 "end_index": 1502,
#                 "uri": "https://github.com/valhareym/AROGYAM"
#               }
#             ]
#           },
#           "avg_logprobs": -0.07544307848986458
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 207,
#         "candidates_token_count": 1088,
#         "total_token_count": 1295
#       },
#       "model_version": "gemini-1.5-flash-latest"
#     }),
# )
#
# ✅ Generated Frontend Code:
#  ```jsx
# import React, { useState, useEffect } from 'react';
#
# const APIS = [
#   { name: 'weather-api', url: 'http://127.0.0.1:8000/weather-api' },
#   { name: 'Tomorrow', url: 'http://127.0.0.1:8000/tomorrow' },
#   { name: 'WeatherAPI', url: 'http://127.0.0.1:8000/weatherapi' },
#   { name: 'apilayer weatherstack', url: 'http://127.0.0.1:8000/apilayer_weatherstack' },
#   { name: 'Weatherstack', url: 'http://127.0.0.1:8000/weatherstack' },
# ];
#
# const WeatherData = () => {
#   const [data, setData] = useState({});
#   const [loading, setLoading] = useState(true);
#   const [error, setError] = useState(null);
#
#   useEffect(() => {
#     const fetchData = async () => {
#       try {
#         const promises = APIS.map(api =>
#           fetch(api.url)
#             .then(res => res.json())
#             .then(data => ({ name: api.name, data }))
#             .catch(error => ({ name: api.name, error }))
#         );
#         const results = await Promise.all(promises);
#         const dataObj = {};
#         results.forEach(result => {
#           if (result.error) {
#             dataObj[result.name] = { error: result.error.message || result.error };
#           } else {
#             dataObj[result.name] = result.data;
#           }
#         });
#         setData(dataObj);
#       } catch (err) {
#         setError(err);
#       } finally {
#         setLoading(false);
#       }
#     };
#
#     fetchData();
#   }, []);
#
#   if (loading) {
#     return <div>Loading...</div>;
#   }
#
#   if (error) {
#     return <div>Error: {error.message}</div>;
#   }
#
#   return (
#     <table>
#       <thead>
#         <tr>
#           <th>API</th>
#           <th>Data</th>
#         </tr>
#       </thead>
#       <tbody>
#         {Object.entries(data).map(([apiName, apiData]) => (
#           <tr key={apiName}>
#             <td>{apiName}</td>
#             <td>
#               {apiData.error ? (
#                 <span style={{ color: 'red' }}>Error: {apiData.error}</span>
#               ) : (
#                 <pre>{JSON.stringify(apiData, null, 2)}</pre>
#               )}
#             </td>
#           </tr>
#         ))}
#       </tbody>
#     </table>
#   );
# };
#
# export default WeatherData;
# ```
#
# **Before running:**
#
# 1.  **Make sure you have a FastAPI server running on `http://127.0.0.1:8000` with the specified endpoints.**  This code assumes those endpoints exist and return JSON data.  You'll need to create those API endpoints yourself.  A simple example for one endpoint might be:
#
#     ```python
#     from fastapi import FastAPI
#     app = FastAPI()
#
#     @app.get("/weather-api")
#     async def weather_api():
#         return {"temperature": 25, "condition": "Sunny"}
#     ```
#
# 2.  **Install React and necessary packages:**  You'll need to have a React project set up.  If not, use `create-react-app`:
#
#     ```bash
#     npx create-react-app my-weather-app
#     cd my-weather-app
#     ```
#
# 3.  **Replace the placeholder API URLs** if your FastAPI server is running on a different address or port.
#
# 4.  **Import and render the component** in your main app file (e.g., `App.js` or `src/App.js`):
#
#     ```jsx
#     import React from 'react';
#     import WeatherData from './WeatherData'; // Adjust path as needed
#
#     function App() {
#       return (
#         <div className="App">
#           <WeatherData />
#         </div>
#       );
#     }
#
#     export default App;
#     ```
#
# 5.  **Run the React app:**
#
#     ```bash
#     npm start
#     ```
#
#
# This improved version handles errors more gracefully, displaying error messages from each API call individually, and uses `pre` tags for better formatting of JSON responses.  Remember to adjust file paths as needed for your project structure.  The error handling assumes the API returns a JSON object with an `error` property or a string message. You might need to adjust this based on your actual error responses.
#
#
# ✅ Frontend Code Generated. ```jsx
# import React, { useState, useEffect } from 'react';
#
# const APIS = [
#   { name: 'weather-api', url: 'http://127.0.0.1:8000/weather-api' },
#   { name: 'Tomorrow', url: 'http://127.0.0.1:8000/tomorrow' },
#   { name: 'WeatherAPI', url: 'http://127.0.0.1:8000/weatherapi' },
#   { name: 'apilayer weatherstack', url: 'http://127.0.0.1:8000/apilayer_weatherstack' },
#   { name: 'Weatherstack', url: 'http://127.0.0.1:8000/weatherstack' },
# ];
#
# const WeatherData = () => {
#   const [data, setData] = useState({});
#   const [loading, setLoading] = useState(true);
#   const [error, setError] = useState(null);
#
#   useEffect(() => {
#     const fetchData = async () => {
#       try {
#         const promises = APIS.map(api =>
#           fetch(api.url)
#             .then(res => res.json())
#             .then(data => ({ name: api.name, data }))
#             .catch(error => ({ name: api.name, error }))
#         );
#         const results = await Promise.all(promises);
#         const dataObj = {};
#         results.forEach(result => {
#           if (result.error) {
#             dataObj[result.name] = { error: result.error.message || result.error };
#           } else {
#             dataObj[result.name] = result.data;
#           }
#         });
#         setData(dataObj);
#       } catch (err) {
#         setError(err);
#       } finally {
#         setLoading(false);
#       }
#     };
#
#     fetchData();
#   }, []);
#
#   if (loading) {
#     return <div>Loading...</div>;
#   }
#
#   if (error) {
#     return <div>Error: {error.message}</div>;
#   }
#
#   return (
#     <table>
#       <thead>
#         <tr>
#           <th>API</th>
#           <th>Data</th>
#         </tr>
#       </thead>
#       <tbody>
#         {Object.entries(data).map(([apiName, apiData]) => (
#           <tr key={apiName}>
#             <td>{apiName}</td>
#             <td>
#               {apiData.error ? (
#                 <span style={{ color: 'red' }}>Error: {apiData.error}</span>
#               ) : (
#                 <pre>{JSON.stringify(apiData, null, 2)}</pre>
#               )}
#             </td>
#           </tr>
#         ))}
#       </tbody>
#     </table>
#   );
# };
#
# export default WeatherData;
# ```
#
# **Before running:**
#
# 1.  **Make sure you have a FastAPI server running on `http://127.0.0.1:8000` with the specified endpoints.**  This code assumes those endpoints exist and return JSON data.  You'll need to create those API endpoints yourself.  A simple example for one endpoint might be:
#
#     ```python
#     from fastapi import FastAPI
#     app = FastAPI()
#
#     @app.get("/weather-api")
#     async def weather_api():
#         return {"temperature": 25, "condition": "Sunny"}
#     ```
#
# 2.  **Install React and necessary packages:**  You'll need to have a React project set up.  If not, use `create-react-app`:
#
#     ```bash
#     npx create-react-app my-weather-app
#     cd my-weather-app
#     ```
#
# 3.  **Replace the placeholder API URLs** if your FastAPI server is running on a different address or port.
#
# 4.  **Import and render the component** in your main app file (e.g., `App.js` or `src/App.js`):
#
#     ```jsx
#     import React from 'react';
#     import WeatherData from './WeatherData'; // Adjust path as needed
#
#     function App() {
#       return (
#         <div className="App">
#           <WeatherData />
#         </div>
#       );
#     }
#
#     export default App;
#     ```
#
# 5.  **Run the React app:**
#
#     ```bash
#     npm start
#     ```
#
#
# This improved version handles errors more gracefully, displaying error messages from each API call individually, and uses `pre` tags for better formatting of JSON responses.  Remember to adjust file paths as needed for your project structure.  The error handling assumes the API returns a JSON object with an `error` property or a string message. You might need to adjust this based on your actual error responses.
